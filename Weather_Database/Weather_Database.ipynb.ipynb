# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries, depends, times, key
import pandas as pd
import numpy as np
import timeit
from citipy import citipy
import time
from datetime import datetime
import requests
import matplotlib.pyplot as plt

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
place_count = 2000 
lats = np.random.uniform(low=-90.000, high=90.000, size=place_count)
lngs = np.random.uniform(low=-180.000, high=180.000, size=place_count)
coordinates = zip(lats, lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 763

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]['main']
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "City Weather":city_description})     
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 2 of Set 1 | kabalo
# Processing Record 3 of Set 1 | kamenka
# Processing Record 4 of Set 1 | tuktoyaktuk
# Processing Record 5 of Set 1 | umm lajj
# Processing Record 6 of Set 1 | nouadhibou
# Processing Record 7 of Set 1 | kindu
# Processing Record 8 of Set 1 | rikitea
# Processing Record 9 of Set 1 | kapaa
# Processing Record 10 of Set 1 | kuche
# City not found. Skipping...
# Processing Record 11 of Set 1 | nexo
# Processing Record 12 of Set 1 | cabo san lucas
# Processing Record 13 of Set 1 | atuona
# Processing Record 14 of Set 1 | ushuaia
# Processing Record 15 of Set 1 | san rafael
# Processing Record 16 of Set 1 | gayny
# Processing Record 17 of Set 1 | bethel
# Processing Record 18 of Set 1 | portobelo
# Processing Record 19 of Set 1 | clyde river
# Processing Record 20 of Set 1 | mikuni
# Processing Record 21 of Set 1 | batagay-alyta
# Processing Record 22 of Set 1 | severo-kurilsk
# Processing Record 23 of Set 1 | saskylakh
# Processing Record 24 of Set 1 | presidente medici
# Processing Record 25 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 26 of Set 1 | ternate
# Processing Record 27 of Set 1 | henties bay
# Processing Record 28 of Set 1 | torbay
# Processing Record 29 of Set 1 | tura
# Processing Record 30 of Set 1 | quatre cocos
# Processing Record 31 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 32 of Set 1 | luderitz
# Processing Record 33 of Set 1 | port alfred
# Processing Record 34 of Set 1 | luwuk
# Processing Record 35 of Set 1 | lazaro cardenas
# Processing Record 36 of Set 1 | guerrero negro
# Processing Record 37 of Set 1 | polovinnoye
# Processing Record 38 of Set 1 | hobart
# Processing Record 39 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 40 of Set 1 | iqaluit
# Processing Record 41 of Set 1 | mahebourg
# Processing Record 42 of Set 1 | te anau
# Processing Record 43 of Set 1 | lata
# Processing Record 44 of Set 1 | jamestown
# Processing Record 45 of Set 1 | talaya
# Processing Record 46 of Set 1 | gat
# Processing Record 47 of Set 1 | vilyuysk
# Processing Record 48 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 49 of Set 1 | punta arenas
# Processing Record 50 of Set 1 | butaritari
# Processing Record 1 of Set 2 | ilulissat
# Processing Record 2 of Set 2 | hermanus
# Processing Record 3 of Set 2 | cape town
# Processing Record 4 of Set 2 | lavrentiya
# Processing Record 5 of Set 2 | urazovo
# Processing Record 6 of Set 2 | albany
# Processing Record 7 of Set 2 | puerto ayora
# Processing Record 8 of Set 2 | amahai
# Processing Record 9 of Set 2 | avarua
# Processing Record 10 of Set 2 | san patricio
# Processing Record 11 of Set 2 | tual
# Processing Record 12 of Set 2 | grahamstown
# Processing Record 13 of Set 2 | itoman
# Processing Record 14 of Set 2 | qaanaaq
# Processing Record 15 of Set 2 | hilo
# Processing Record 16 of Set 2 | sao gabriel da cachoeira
# Processing Record 17 of Set 2 | carnarvon
# Processing Record 18 of Set 2 | yellowknife
# Processing Record 19 of Set 2 | bambous virieux
# Processing Record 20 of Set 2 | nchelenge
# Processing Record 21 of Set 2 | darhan
# Processing Record 22 of Set 2 | tuatapere
# Processing Record 23 of Set 2 | vaini
# Processing Record 24 of Set 2 | bargal
# City not found. Skipping...
# Processing Record 25 of Set 2 | thompson
# Processing Record 26 of Set 2 | rochegda
# Processing Record 27 of Set 2 | dikson
# Processing Record 28 of Set 2 | airai
# Processing Record 29 of Set 2 | georgetown
# Processing Record 30 of Set 2 | adrar
# Processing Record 31 of Set 2 | castro
# Processing Record 32 of Set 2 | thunder bay
# Processing Record 33 of Set 2 | cotonou
# Processing Record 34 of Set 2 | saint-philippe
# Processing Record 35 of Set 2 | eyl
# Processing Record 36 of Set 2 | souillac
# Processing Record 37 of Set 2 | lebu
# Processing Record 38 of Set 2 | chuy
# Processing Record 39 of Set 2 | ancud
# Processing Record 40 of Set 2 | nantucket
# Processing Record 41 of Set 2 | itapirapua
# Processing Record 42 of Set 2 | mount isa
# Processing Record 43 of Set 2 | pevek
# Processing Record 44 of Set 2 | pangnirtung
# Processing Record 45 of Set 2 | nioro
# Processing Record 46 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 47 of Set 2 | flinders
# Processing Record 48 of Set 2 | busselton
# Processing Record 49 of Set 2 | lorengau
# Processing Record 50 of Set 2 | nosivka
# Processing Record 1 of Set 3 | bilibino
# Processing Record 2 of Set 3 | shelburne
# Processing Record 3 of Set 3 | vao
# Processing Record 4 of Set 3 | kutum
# Processing Record 5 of Set 3 | labuhan
# Processing Record 6 of Set 3 | mataura
# Processing Record 7 of Set 3 | hithadhoo
# Processing Record 8 of Set 3 | rio grande
# Processing Record 9 of Set 3 | khatanga
# Processing Record 10 of Set 3 | morondava
# Processing Record 11 of Set 3 | noyabrsk
# Processing Record 12 of Set 3 | shache
# Processing Record 13 of Set 3 | mar del plata
# Processing Record 14 of Set 3 | pangkalanbuun
# Processing Record 15 of Set 3 | terney
# Processing Record 16 of Set 3 | norman wells
# Processing Record 17 of Set 3 | beringovskiy
# Processing Record 18 of Set 3 | camana
# Processing Record 19 of Set 3 | hammerfest
# Processing Record 20 of Set 3 | paamiut
# Processing Record 21 of Set 3 | ngukurr
# City not found. Skipping...
# Processing Record 22 of Set 3 | saldanha
# Processing Record 23 of Set 3 | bambanglipuro
# Processing Record 24 of Set 3 | manggar
# Processing Record 25 of Set 3 | seymchan
# Processing Record 26 of Set 3 | cidreira
# Processing Record 27 of Set 3 | ponta do sol
# Processing Record 28 of Set 3 | bluff
# Processing Record 29 of Set 3 | plesetsk
# Processing Record 30 of Set 3 | anadyr
# Processing Record 31 of Set 3 | isangel
# Processing Record 32 of Set 3 | kiruna
# Processing Record 33 of Set 3 | penon blanco
# Processing Record 34 of Set 3 | bajos de haina
# Processing Record 35 of Set 3 | tottori
# Processing Record 36 of Set 3 | dingle
# Processing Record 37 of Set 3 | dudinka
# Processing Record 38 of Set 3 | nan
# Processing Record 39 of Set 3 | chiguiri arriba
# City not found. Skipping...
# Processing Record 40 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 41 of Set 3 | geraldton
# Processing Record 42 of Set 3 | iberia
# Processing Record 43 of Set 3 | sinnamary
# Processing Record 44 of Set 3 | tasiilaq
# Processing Record 45 of Set 3 | new norfolk
# Processing Record 46 of Set 3 | takoradi
# Processing Record 47 of Set 3 | baft
# Processing Record 48 of Set 3 | yar-sale
# Processing Record 49 of Set 3 | finschhafen
# Processing Record 50 of Set 3 | batagay
# Processing Record 1 of Set 4 | zharkovskiy
# Processing Record 2 of Set 4 | bredasdorp
# Processing Record 3 of Set 4 | urfa
# City not found. Skipping...
# Processing Record 4 of Set 4 | dolores
# Processing Record 5 of Set 4 | buala
# Processing Record 6 of Set 4 | faanui
# Processing Record 7 of Set 4 | san cristobal
# Processing Record 8 of Set 4 | seinajoki
# Processing Record 9 of Set 4 | yulara
# Processing Record 10 of Set 4 | gorontalo
# Processing Record 11 of Set 4 | ribeira grande
# Processing Record 12 of Set 4 | semme
# Processing Record 13 of Set 4 | east london
# Processing Record 14 of Set 4 | burnie
# Processing Record 15 of Set 4 | cherskiy
# Processing Record 16 of Set 4 | castrovillari
# Processing Record 17 of Set 4 | matara
# Processing Record 18 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 19 of Set 4 | tawang
# Processing Record 20 of Set 4 | lasa
# Processing Record 21 of Set 4 | emirdag
# Processing Record 22 of Set 4 | akyab
# Processing Record 23 of Set 4 | acarau
# Processing Record 24 of Set 4 | malpe
# Processing Record 25 of Set 4 | upernavik
# Processing Record 26 of Set 4 | katsuura
# Processing Record 27 of Set 4 | tuy hoa
# Processing Record 28 of Set 4 | praxedis guerrero
# Processing Record 29 of Set 4 | bengkulu
# Processing Record 30 of Set 4 | kattivakkam
# Processing Record 31 of Set 4 | kirakira
# Processing Record 32 of Set 4 | ugoofaaru
# Processing Record 33 of Set 4 | karachi
# Processing Record 34 of Set 4 | alofi
# Processing Record 35 of Set 4 | gurskoye
# City not found. Skipping...
# Processing Record 36 of Set 4 | cayenne
# Processing Record 37 of Set 4 | chokurdakh
# Processing Record 38 of Set 4 | shibarghan
# City not found. Skipping...
# Processing Record 39 of Set 4 | pozhva
# Processing Record 40 of Set 4 | leeuwarden
# Processing Record 41 of Set 4 | touros
# Processing Record 42 of Set 4 | sitka
# Processing Record 43 of Set 4 | esperance
# Processing Record 44 of Set 4 | faya
# Processing Record 45 of Set 4 | codrington
# Processing Record 46 of Set 4 | hailar
# Processing Record 47 of Set 4 | burica
# City not found. Skipping...
# Processing Record 48 of Set 4 | vylgort
# City not found. Skipping...
# Processing Record 49 of Set 4 | antsohihy
# Processing Record 50 of Set 4 | tagab
# Processing Record 1 of Set 5 | longyearbyen
# Processing Record 2 of Set 5 | dubrovnik
# Processing Record 3 of Set 5 | jining
# Processing Record 4 of Set 5 | port-gentil
# Processing Record 5 of Set 5 | harnosand
# Processing Record 6 of Set 5 | marawi
# Processing Record 7 of Set 5 | artyk
# City not found. Skipping...
# Processing Record 8 of Set 5 | arlit
# Processing Record 9 of Set 5 | kaihua
# Processing Record 10 of Set 5 | zaragoza
# Processing Record 11 of Set 5 | chara
# Processing Record 12 of Set 5 | malanje
# Processing Record 13 of Set 5 | oksfjord
# Processing Record 14 of Set 5 | sabha
# Processing Record 15 of Set 5 | manuk mangkaw
# Processing Record 16 of Set 5 | san quintin
# Processing Record 17 of Set 5 | amarillo
# Processing Record 18 of Set 5 | constitucion
# Processing Record 19 of Set 5 | nemuro
# Processing Record 20 of Set 5 | richards bay
# Processing Record 21 of Set 5 | bongandanga
# Processing Record 22 of Set 5 | tabou
# Processing Record 23 of Set 5 | madras
# Processing Record 24 of Set 5 | beira
# Processing Record 25 of Set 5 | aykhal
# Processing Record 26 of Set 5 | saint george
# Processing Record 27 of Set 5 | winnemucca
# Processing Record 28 of Set 5 | hambantota
# Processing Record 29 of Set 5 | victoria
# Processing Record 30 of Set 5 | abalak
# Processing Record 31 of Set 5 | broken hill
# Processing Record 32 of Set 5 | halalo
# City not found. Skipping...
# Processing Record 33 of Set 5 | camacha
# Processing Record 34 of Set 5 | aksarka
# Processing Record 35 of Set 5 | chicama
# Processing Record 36 of Set 5 | kavieng
# Processing Record 37 of Set 5 | bodden town
# Processing Record 38 of Set 5 | yanai
# Processing Record 39 of Set 5 | sanmenxia
# Processing Record 40 of Set 5 | gwadar
# Processing Record 41 of Set 5 | kahului
# Processing Record 42 of Set 5 | gao
# Processing Record 43 of Set 5 | vermilion
# Processing Record 44 of Set 5 | yanaul
# Processing Record 45 of Set 5 | lesnyye polyany
# Processing Record 46 of Set 5 | axim
# Processing Record 47 of Set 5 | vila franca do campo
# Processing Record 48 of Set 5 | makakilo city
# Processing Record 49 of Set 5 | pindi bhattian
# Processing Record 50 of Set 5 | calabozo
# Processing Record 1 of Set 6 | nikolskoye
# Processing Record 2 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 3 of Set 6 | chilca
# Processing Record 4 of Set 6 | klaksvik
# Processing Record 5 of Set 6 | sao filipe
# Processing Record 6 of Set 6 | vesyegonsk
# Processing Record 7 of Set 6 | bolungarvik
# City not found. Skipping...
# Processing Record 8 of Set 6 | pitimbu
# Processing Record 9 of Set 6 | naze
# Processing Record 10 of Set 6 | nishihara
# Processing Record 11 of Set 6 | miass
# Processing Record 12 of Set 6 | ardahan
# Processing Record 13 of Set 6 | fare
# Processing Record 14 of Set 6 | palmer
# Processing Record 15 of Set 6 | birjand
# Processing Record 16 of Set 6 | saint-joseph
# Processing Record 17 of Set 6 | tadine
# Processing Record 18 of Set 6 | port lincoln
# Processing Record 19 of Set 6 | port elizabeth
# Processing Record 20 of Set 6 | turmalina
# Processing Record 21 of Set 6 | vostok
# Processing Record 22 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 23 of Set 6 | shimoda
# Processing Record 24 of Set 6 | channel-port aux basques
# Processing Record 25 of Set 6 | srandakan
# Processing Record 26 of Set 6 | lixourion
# Processing Record 27 of Set 6 | ilabaya
# Processing Record 28 of Set 6 | nelson bay
# Processing Record 29 of Set 6 | elesbao veloso
# Processing Record 30 of Set 6 | bunbury
# Processing Record 31 of Set 6 | talnakh
# Processing Record 32 of Set 6 | pestyaki
# Processing Record 33 of Set 6 | chingola
# Processing Record 34 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 35 of Set 6 | kaitangata
# Processing Record 36 of Set 6 | hofn
# Processing Record 37 of Set 6 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 38 of Set 6 | weingarten
# Processing Record 39 of Set 6 | coquimbo
# Processing Record 40 of Set 6 | ushtobe
# Processing Record 41 of Set 6 | nouakchott
# Processing Record 42 of Set 6 | constancia
# Processing Record 43 of Set 6 | korsakov
# Processing Record 44 of Set 6 | lagoa
# Processing Record 45 of Set 6 | vila velha
# Processing Record 46 of Set 6 | rocky mountain house
# Processing Record 47 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 48 of Set 6 | huambo
# Processing Record 49 of Set 6 | dryden
# Processing Record 50 of Set 6 | arraial do cabo
# Processing Record 1 of Set 7 | nieuw amsterdam
# Processing Record 2 of Set 7 | awbari
# Processing Record 3 of Set 7 | neuquen
# Processing Record 4 of Set 7 | yirol
# City not found. Skipping...
# Processing Record 5 of Set 7 | tikapur
# Processing Record 6 of Set 7 | kodiak
# Processing Record 7 of Set 7 | barrow
# Processing Record 8 of Set 7 | tiznit
# Processing Record 9 of Set 7 | fairmont
# Processing Record 10 of Set 7 | ustka
# Processing Record 11 of Set 7 | barcelos
# Processing Record 12 of Set 7 | tateyama
# Processing Record 13 of Set 7 | chagda
# City not found. Skipping...
# Processing Record 14 of Set 7 | xai-xai
# Processing Record 15 of Set 7 | sirnak
# Processing Record 16 of Set 7 | college
# Processing Record 17 of Set 7 | roald
# Processing Record 18 of Set 7 | biak
# Processing Record 19 of Set 7 | batangafo
# Processing Record 20 of Set 7 | kavaratti
# Processing Record 21 of Set 7 | khorixas
# Processing Record 22 of Set 7 | reconquista
# Processing Record 23 of Set 7 | swan hill
# Processing Record 24 of Set 7 | mount gambier
# Processing Record 25 of Set 7 | awjilah
# Processing Record 26 of Set 7 | muromtsevo
# Processing Record 27 of Set 7 | barentsburg
# City not found. Skipping...
# Processing Record 28 of Set 7 | brooks
# Processing Record 29 of Set 7 | sarakhs
# Processing Record 30 of Set 7 | haibowan
# City not found. Skipping...
# Processing Record 31 of Set 7 | mgandu
# Processing Record 32 of Set 7 | dillon
# Processing Record 33 of Set 7 | merauke
# Processing Record 34 of Set 7 | presidencia roque saenz pena
# Processing Record 35 of Set 7 | the valley
# Processing Record 36 of Set 7 | eureka
# Processing Record 37 of Set 7 | tessalit
# Processing Record 38 of Set 7 | rawlins
# Processing Record 39 of Set 7 | dzaoudzi
# Processing Record 40 of Set 7 | buariki
# City not found. Skipping...
# Processing Record 41 of Set 7 | taburi
# City not found. Skipping...
# Processing Record 42 of Set 7 | killybegs
# Processing Record 43 of Set 7 | primorsk
# Processing Record 44 of Set 7 | nazira
# Processing Record 45 of Set 7 | tofield
# Processing Record 46 of Set 7 | tanout
# Processing Record 47 of Set 7 | noumea
# Processing Record 48 of Set 7 | jabinyanah
# Processing Record 49 of Set 7 | beja
# Processing Record 50 of Set 7 | cherepanovo
# Processing Record 1 of Set 8 | astana
# Processing Record 2 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 3 of Set 8 | santa vitoria do palmar
# Processing Record 4 of Set 8 | silchar
# Processing Record 5 of Set 8 | mahibadhoo
# Processing Record 6 of Set 8 | banda aceh
# Processing Record 7 of Set 8 | padang
# Processing Record 8 of Set 8 | port blair
# Processing Record 9 of Set 8 | abadszalok
# Processing Record 10 of Set 8 | hualmay
# Processing Record 11 of Set 8 | pacific grove
# Processing Record 12 of Set 8 | rockland
# Processing Record 13 of Set 8 | korla
# Processing Record 14 of Set 8 | truth or consequences
# Processing Record 15 of Set 8 | russell
# Processing Record 16 of Set 8 | zapadnaya dvina
# Processing Record 17 of Set 8 | yatou
# Processing Record 18 of Set 8 | osoyoos
# Processing Record 19 of Set 8 | dakar
# Processing Record 20 of Set 8 | whitley bay
# Processing Record 21 of Set 8 | rio gallegos
# Processing Record 22 of Set 8 | weihai
# Processing Record 23 of Set 8 | mayo
# Processing Record 24 of Set 8 | ostrovnoy
# Processing Record 25 of Set 8 | amderma
# City not found. Skipping...
# Processing Record 26 of Set 8 | qaqortoq
# Processing Record 27 of Set 8 | ossora
# Processing Record 28 of Set 8 | vzmorye
# Processing Record 29 of Set 8 | pisco
# Processing Record 30 of Set 8 | dzhusaly
# City not found. Skipping...
# Processing Record 31 of Set 8 | ayat
# Processing Record 32 of Set 8 | kandrian
# Processing Record 33 of Set 8 | los llanos de aridane
# Processing Record 34 of Set 8 | karlstad
# Processing Record 35 of Set 8 | viligili
# City not found. Skipping...
# Processing Record 36 of Set 8 | sobolevo
# Processing Record 37 of Set 8 | akdepe
# Processing Record 38 of Set 8 | povenets
# Processing Record 39 of Set 8 | hasaki
# Processing Record 40 of Set 8 | kaeng khoi
# Processing Record 41 of Set 8 | porto-vecchio
# Processing Record 42 of Set 8 | santona
# Processing Record 43 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 44 of Set 8 | sahrak
# City not found. Skipping...
# Processing Record 45 of Set 8 | malyn
# Processing Record 46 of Set 8 | karakendzha
# City not found. Skipping...
# Processing Record 47 of Set 8 | unai
# Processing Record 48 of Set 8 | auki
# Processing Record 49 of Set 8 | pierre
# Processing Record 50 of Set 8 | huicheng
# Processing Record 1 of Set 9 | hamilton
# Processing Record 2 of Set 9 | jumla
# Processing Record 3 of Set 9 | benito juarez
# Processing Record 4 of Set 9 | mairwa
# Processing Record 5 of Set 9 | ngunguru
# Processing Record 6 of Set 9 | haines junction
# Processing Record 7 of Set 9 | avanigadda
# Processing Record 8 of Set 9 | fairbanks
# Processing Record 9 of Set 9 | bam
# Processing Record 10 of Set 9 | dezhou
# Processing Record 11 of Set 9 | sanbu
# Processing Record 12 of Set 9 | manta
# Processing Record 13 of Set 9 | aklavik
# Processing Record 14 of Set 9 | yian
# City not found. Skipping...
# Processing Record 15 of Set 9 | elko
# Processing Record 16 of Set 9 | envira
# Processing Record 17 of Set 9 | chumikan
# Processing Record 18 of Set 9 | wilmington
# Processing Record 19 of Set 9 | bouar
# Processing Record 20 of Set 9 | batemans bay
# Processing Record 21 of Set 9 | nguiu
# City not found. Skipping...
# Processing Record 22 of Set 9 | fengrun
# Processing Record 23 of Set 9 | ahipara
# Processing Record 24 of Set 9 | avera
# Processing Record 25 of Set 9 | port moresby
# Processing Record 26 of Set 9 | san luis
# Processing Record 27 of Set 9 | tiksi
# Processing Record 28 of Set 9 | crab hill
# City not found. Skipping...
# Processing Record 29 of Set 9 | emba
# Processing Record 30 of Set 9 | sayanogorsk
# Processing Record 31 of Set 9 | baruun-urt
# Processing Record 32 of Set 9 | lanzhou
# Processing Record 33 of Set 9 | rawson
# Processing Record 34 of Set 9 | namatanai
# Processing Record 35 of Set 9 | doha
# Processing Record 36 of Set 9 | anahuac
# Processing Record 37 of Set 9 | smolenka
# Processing Record 38 of Set 9 | faridan
# City not found. Skipping...
# Processing Record 39 of Set 9 | bandarbeyla
# Processing Record 40 of Set 9 | kholodnyy
# Processing Record 41 of Set 9 | orlik
# Processing Record 42 of Set 9 | port hardy
# Processing Record 43 of Set 9 | marrakesh
# Processing Record 44 of Set 9 | yining
# Processing Record 45 of Set 9 | krasnoselkup
# Processing Record 46 of Set 9 | mayor pablo lagerenza
# Processing Record 47 of Set 9 | portland
# Processing Record 48 of Set 9 | cherdyn
# Processing Record 49 of Set 9 | macieira de cambra
# Processing Record 50 of Set 9 | kyzyl
# Processing Record 1 of Set 10 | pandaan
# Processing Record 2 of Set 10 | imeni poliny osipenko
# Processing Record 3 of Set 10 | berlevag
# Processing Record 4 of Set 10 | tillabery
# City not found. Skipping...
# Processing Record 5 of Set 10 | khorinsk
# Processing Record 6 of Set 10 | leeds
# Processing Record 7 of Set 10 | fortuna
# Processing Record 8 of Set 10 | komsomolskiy
# Processing Record 9 of Set 10 | santander jimenez
# Processing Record 10 of Set 10 | magadan
# Processing Record 11 of Set 10 | maniitsoq
# Processing Record 12 of Set 10 | gold coast
# Processing Record 13 of Set 10 | simpang
# Processing Record 14 of Set 10 | bairiki
# Processing Record 15 of Set 10 | necochea
# Processing Record 16 of Set 10 | gushikawa
# Processing Record 17 of Set 10 | tefe
# Processing Record 18 of Set 10 | sorland
# Processing Record 19 of Set 10 | coahuayana
# Processing Record 20 of Set 10 | sao joao da barra
# Processing Record 21 of Set 10 | drovyanaya
# Processing Record 22 of Set 10 | birao
# Processing Record 23 of Set 10 | porto santo
# Processing Record 24 of Set 10 | myski
# Processing Record 25 of Set 10 | kalabo
# Processing Record 26 of Set 10 | waipawa
# Processing Record 27 of Set 10 | glens falls
# Processing Record 28 of Set 10 | yarkovo
# Processing Record 29 of Set 10 | lakes entrance
# Processing Record 30 of Set 10 | milkovo
# Processing Record 31 of Set 10 | obo
# Processing Record 32 of Set 10 | udachnyy
# Processing Record 33 of Set 10 | praia da vitoria
# Processing Record 34 of Set 10 | baculin
# Processing Record 35 of Set 10 | omsukchan
# Processing Record 36 of Set 10 | qalyub
# Processing Record 37 of Set 10 | altamira
# Processing Record 38 of Set 10 | neryungri
# Processing Record 39 of Set 10 | batticaloa
# Processing Record 40 of Set 10 | salo
# Processing Record 41 of Set 10 | hvolsvollur
# Processing Record 42 of Set 10 | linhares
# Processing Record 43 of Set 10 | nome
# Processing Record 44 of Set 10 | belaya gora
# Processing Record 45 of Set 10 | hellvik
# Processing Record 46 of Set 10 | ica
# Processing Record 47 of Set 10 | banjar
# Processing Record 48 of Set 10 | hotaka
# Processing Record 49 of Set 10 | houma
# Processing Record 50 of Set 10 | ayan
# Processing Record 1 of Set 11 | dera ghazi khan
# Processing Record 2 of Set 11 | innisfail
# Processing Record 3 of Set 11 | bay roberts
# Processing Record 4 of Set 11 | ponta delgada
# Processing Record 5 of Set 11 | muisne
# Processing Record 6 of Set 11 | oistins
# Processing Record 7 of Set 11 | sinkat
# City not found. Skipping...
# Processing Record 8 of Set 11 | karamay
# City not found. Skipping...
# Processing Record 9 of Set 11 | provideniya
# Processing Record 10 of Set 11 | verkhnyaya pyshma
# Processing Record 11 of Set 11 | kloulklubed
# Processing Record 12 of Set 11 | pavda
# City not found. Skipping...
# Processing Record 13 of Set 11 | balkanabat
# Processing Record 14 of Set 11 | aleksandrov gay
# Processing Record 15 of Set 11 | bemidji
# Processing Record 16 of Set 11 | novovasylivka
# Processing Record 17 of Set 11 | ningan
# City not found. Skipping...
# Processing Record 18 of Set 11 | olga
# Processing Record 19 of Set 11 | vardo
# Processing Record 20 of Set 11 | asfi
# Processing Record 21 of Set 11 | caidian
# Processing Record 22 of Set 11 | antofagasta
# Processing Record 23 of Set 11 | shiyan
# Processing Record 24 of Set 11 | fenelon falls
# Processing Record 25 of Set 11 | laguna
# Processing Record 26 of Set 11 | vaitupu
# City not found. Skipping...
# Processing Record 27 of Set 11 | tidore
# City not found. Skipping...
# Processing Record 28 of Set 11 | lhokseumawe
# Processing Record 29 of Set 11 | karaul
# City not found. Skipping...
# Processing Record 30 of Set 11 | high rock
# Processing Record 31 of Set 11 | north arlington
# Processing Record 32 of Set 11 | saint-ambroise
# Processing Record 33 of Set 11 | taoudenni
# Processing Record 34 of Set 11 | yerbogachen
# Processing Record 35 of Set 11 | kaka
# Processing Record 36 of Set 11 | moranbah
# Processing Record 37 of Set 11 | mpika
# Processing Record 38 of Set 11 | iracoubo
# Processing Record 39 of Set 11 | taungdwingyi
# Processing Record 40 of Set 11 | nizhneyansk
# City not found. Skipping...
# Processing Record 41 of Set 11 | niimi
# Processing Record 42 of Set 11 | salinas
# Processing Record 43 of Set 11 | urengoy
# Processing Record 44 of Set 11 | orsha
# Processing Record 45 of Set 11 | dzhebariki-khaya
# Processing Record 46 of Set 11 | qiongshan
# Processing Record 47 of Set 11 | tazovskiy
# Processing Record 48 of Set 11 | berndorf
# Processing Record 49 of Set 11 | aasiaat
# Processing Record 50 of Set 11 | ejido
# Processing Record 1 of Set 12 | viransehir
# Processing Record 2 of Set 12 | qasigiannguit
# Processing Record 3 of Set 12 | kodinsk
# Processing Record 4 of Set 12 | goderich
# Processing Record 5 of Set 12 | krasnyy chikoy
# Processing Record 6 of Set 12 | acapulco
# Processing Record 7 of Set 12 | kashi
# Processing Record 8 of Set 12 | samusu
# City not found. Skipping...
# Processing Record 9 of Set 12 | kutahya
# Processing Record 10 of Set 12 | nova gradiska
# Processing Record 11 of Set 12 | diego de almagro
# Processing Record 12 of Set 12 | thinadhoo
# Processing Record 13 of Set 12 | inhambane
# Processing Record 14 of Set 12 | morehead
# Processing Record 15 of Set 12 | mandan
# Processing Record 16 of Set 12 | buritis
# Processing Record 17 of Set 12 | vanimo
# Processing Record 18 of Set 12 | ljungby
# Processing Record 19 of Set 12 | paita
# Processing Record 20 of Set 12 | eirunepe
# Processing Record 21 of Set 12 | jalpan
# Processing Record 22 of Set 12 | kamenskoye
# City not found. Skipping...
# Processing Record 23 of Set 12 | sembe
# Processing Record 24 of Set 12 | stekolnyy
# City not found. Skipping...
# Processing Record 25 of Set 12 | itaqui
# Processing Record 26 of Set 12 | kruisfontein
# Processing Record 27 of Set 12 | altamont
# Processing Record 28 of Set 12 | uyemskiy
# Processing Record 29 of Set 12 | haileybury
# Processing Record 30 of Set 12 | tasbuget
# City not found. Skipping...
# Processing Record 31 of Set 12 | kuruman
# Processing Record 32 of Set 12 | kashan
# Processing Record 33 of Set 12 | tarata
# Processing Record 34 of Set 12 | partsa
# Processing Record 35 of Set 12 | katha
# City not found. Skipping...
# Processing Record 36 of Set 12 | emerald
# Processing Record 37 of Set 12 | kegayli
# City not found. Skipping...
# Processing Record 38 of Set 12 | chernyshevskiy
# Processing Record 39 of Set 12 | pangody
# Processing Record 40 of Set 12 | egvekinot
# Processing Record 41 of Set 12 | sompeta
# Processing Record 42 of Set 12 | verkhnevilyuysk
# Processing Record 43 of Set 12 | polunochnoye
# Processing Record 44 of Set 12 | yelan
# Processing Record 45 of Set 12 | namtsy
# Processing Record 46 of Set 12 | port shepstone
# Processing Record 47 of Set 12 | asyut
# Processing Record 48 of Set 12 | punta cardon
# Processing Record 49 of Set 12 | lima
# Processing Record 50 of Set 12 | salta
# Processing Record 1 of Set 13 | peniche
# Processing Record 2 of Set 13 | sinop
# Processing Record 3 of Set 13 | mackay
# Processing Record 4 of Set 13 | issoire
# Processing Record 5 of Set 13 | siwani
# City not found. Skipping...
# Processing Record 6 of Set 13 | ondjiva
# Processing Record 7 of Set 13 | puerto carreno
# Processing Record 8 of Set 13 | requena
# Processing Record 9 of Set 13 | armidale
# Processing Record 10 of Set 13 | hof
# Processing Record 11 of Set 13 | gari
# Processing Record 12 of Set 13 | bur gabo
# City not found. Skipping...
# Processing Record 13 of Set 13 | satitoa
# City not found. Skipping...
# Processing Record 14 of Set 13 | carmen
# Processing Record 15 of Set 13 | hami
# Processing Record 16 of Set 13 | tabuk
# Processing Record 17 of Set 13 | lerwick
# Processing Record 18 of Set 13 | tsienyane
# City not found. Skipping...
# Processing Record 19 of Set 13 | bousso
# Processing Record 20 of Set 13 | hagi
# Processing Record 21 of Set 13 | labuan
# Processing Record 22 of Set 13 | sogdiondon
# City not found. Skipping...
# Processing Record 23 of Set 13 | pestisani
# Processing Record 24 of Set 13 | zalantun
# Processing Record 25 of Set 13 | rio branco
# Processing Record 26 of Set 13 | taicheng
# Processing Record 27 of Set 13 | salto
# Processing Record 28 of Set 13 | camflora
# City not found. Skipping...
# Processing Record 29 of Set 13 | amalapuram
# Processing Record 30 of Set 13 | lincoln park
# Processing Record 31 of Set 13 | bignona
# Processing Record 32 of Set 13 | nur
# Processing Record 33 of Set 13 | bonavista
# Processing Record 34 of Set 13 | monrovia
# Processing Record 35 of Set 13 | alyangula
# Processing Record 36 of Set 13 | mehamn
# Processing Record 37 of Set 13 | miraflores
# Processing Record 38 of Set 13 | gravdal
# Processing Record 39 of Set 13 | moron
# Processing Record 40 of Set 13 | barrhead
# Processing Record 41 of Set 13 | ilhabela
# Processing Record 42 of Set 13 | morwell
# Processing Record 43 of Set 13 | adre
# Processing Record 44 of Set 13 | honiara
# Processing Record 45 of Set 13 | cascais
# Processing Record 46 of Set 13 | cabra
# Processing Record 47 of Set 13 | stoina
# Processing Record 48 of Set 13 | genhe
# Processing Record 49 of Set 13 | wanning
# Processing Record 50 of Set 13 | hare bay
# Processing Record 1 of Set 14 | fort william
# Processing Record 2 of Set 14 | sawtell
# Processing Record 3 of Set 14 | matay
# Processing Record 4 of Set 14 | otorohanga
# Processing Record 5 of Set 14 | narsaq
# Processing Record 6 of Set 14 | inta
# Processing Record 7 of Set 14 | payo
# Processing Record 8 of Set 14 | turuvekere
# Processing Record 9 of Set 14 | we
# City not found. Skipping...
# Processing Record 10 of Set 14 | ladario
# Processing Record 11 of Set 14 | beloha
# Processing Record 12 of Set 14 | caceres
# Processing Record 13 of Set 14 | caravelas
# Processing Record 14 of Set 14 | micheweni
# Processing Record 15 of Set 14 | koulikoro
# Processing Record 16 of Set 14 | svetlogorsk
# Processing Record 17 of Set 14 | batetskiy
# Processing Record 18 of Set 14 | mizan teferi
# Processing Record 19 of Set 14 | grindavik
# Processing Record 20 of Set 14 | pinega
# Processing Record 21 of Set 14 | yuanping
# Processing Record 22 of Set 14 | agen
# Processing Record 23 of Set 14 | bud
# Processing Record 24 of Set 14 | wukari
# Processing Record 25 of Set 14 | rocha
# Processing Record 26 of Set 14 | samarai
# Processing Record 27 of Set 14 | balezino
# Processing Record 28 of Set 14 | sarangani
# Processing Record 29 of Set 14 | saint-georges
# Processing Record 30 of Set 14 | tigil
# Processing Record 31 of Set 14 | mont-de-marsan
# Processing Record 32 of Set 14 | farafangana
# Processing Record 33 of Set 14 | cockburn town
# Processing Record 34 of Set 14 | akonolinga
# Processing Record 35 of Set 14 | orkney
# Processing Record 36 of Set 14 | narasannapeta
# Processing Record 37 of Set 14 | dongsheng
# Processing Record 38 of Set 14 | beroroha
# Processing Record 39 of Set 14 | alanya
# Processing Record 40 of Set 14 | kazalinsk
# City not found. Skipping...
# Processing Record 41 of Set 14 | bida
# Processing Record 42 of Set 14 | borujan
# City not found. Skipping...
# Processing Record 43 of Set 14 | itaguacu
# Processing Record 44 of Set 14 | salalah
# Processing Record 45 of Set 14 | meulaboh
# Processing Record 46 of Set 14 | lundazi
# Processing Record 47 of Set 14 | roebourne
# Processing Record 48 of Set 14 | portales
# Processing Record 49 of Set 14 | ijaki
# City not found. Skipping...
# Processing Record 50 of Set 14 | lensk
# Processing Record 1 of Set 15 | huarmey
# Processing Record 2 of Set 15 | namibe
# Processing Record 3 of Set 15 | shenzhen
# Processing Record 4 of Set 15 | tezu
# Processing Record 5 of Set 15 | zapolyarnyy
# Processing Record 6 of Set 15 | coihaique
# Processing Record 7 of Set 15 | catbalogan
# Processing Record 8 of Set 15 | chapleau
# Processing Record 9 of Set 15 | alice springs
# Processing Record 10 of Set 15 | orel-izumrud
# Processing Record 11 of Set 15 | aguimes
# Processing Record 12 of Set 15 | great bend
# Processing Record 13 of Set 15 | plettenberg bay
# Processing Record 14 of Set 15 | atambua
# Processing Record 15 of Set 15 | puerto del rosario
# Processing Record 16 of Set 15 | kyren
# Processing Record 17 of Set 15 | grimari
# City not found. Skipping...
# Processing Record 18 of Set 15 | huanren
# Processing Record 19 of Set 15 | olinda
# Processing Record 20 of Set 15 | lavumisa
# Processing Record 21 of Set 15 | nanortalik
# Processing Record 22 of Set 15 | mehran
# Processing Record 23 of Set 15 | ndele
# Processing Record 24 of Set 15 | zlobin
# Processing Record 25 of Set 15 | waddan
# Processing Record 26 of Set 15 | kambove
# Processing Record 27 of Set 15 | beruwala
# Processing Record 28 of Set 15 | tautira
# Processing Record 29 of Set 15 | husavik
# Processing Record 30 of Set 15 | mrirt
# City not found. Skipping...
# Processing Record 31 of Set 15 | valparaiso
# Processing Record 32 of Set 15 | thung song
# Processing Record 33 of Set 15 | rayachoti
# Processing Record 34 of Set 15 | aripuana
# Processing Record 35 of Set 15 | tahta
# Processing Record 36 of Set 15 | heihe
# Processing Record 37 of Set 15 | mossoro
# Processing Record 38 of Set 15 | iquique
# Processing Record 39 of Set 15 | sola
# Processing Record 40 of Set 15 | gamba
# Processing Record 41 of Set 15 | boa vista
# Processing Record 42 of Set 15 | koygorodok
# Processing Record 43 of Set 15 | tooele
# Processing Record 44 of Set 15 | leshukonskoye
# Processing Record 45 of Set 15 | zhangye
# Processing Record 46 of Set 15 | sakakah
# Processing Record 47 of Set 15 | metehara
# City not found. Skipping...
# Processing Record 48 of Set 15 | sibolga
# Processing Record 49 of Set 15 | chatsu
# City not found. Skipping...
# Processing Record 50 of Set 15 | muzhi
# Processing Record 1 of Set 16 | angoram
# Processing Record 2 of Set 16 | barra patuca
# Processing Record 3 of Set 16 | deputatskiy
# Processing Record 4 of Set 16 | saint-pierre
# Processing Record 5 of Set 16 | port keats
# Processing Record 6 of Set 16 | yingshang
# City not found. Skipping...
# Processing Record 7 of Set 16 | pauini
# Processing Record 8 of Set 16 | baykit
# Processing Record 9 of Set 16 | tabas
# Processing Record 10 of Set 16 | olafsvik
# Processing Record 11 of Set 16 | san fernando
# Processing Record 12 of Set 16 | carutapera
# Processing Record 13 of Set 16 | garoua
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 692

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Kabalo  -6.0500   26.9167     70.45        96         100
# 1         Kamenka  51.3223   42.7678     28.18        96         100
# 2     Tuktoyaktuk  69.4541 -133.0374    -25.60        68          75
# 3        Umm Lajj  25.0213   37.2685     71.71        62          81
# 4      Nouadhibou  20.9310  -17.0347     66.18        72          87
# 5           Kindu  -2.9500   25.9500     73.96        86         100
# 6         Rikitea -23.1203 -134.9692     79.77        74          13
# 7           Kapaa  22.0752 -159.3190     80.58        85         100
# 8            Nexo  55.0607   15.1306     39.29        83         100
# 9  Cabo San Lucas  22.8909 -109.9124     80.62        50           0
#
#    Wind Speed Country                 Date City Weather
# 0        4.14      CD  2023-02-19 21:37:03       Clouds
# 1        8.86      RU  2023-02-19 21:37:04       Clouds
# 2        5.75      CA  2023-02-19 21:37:04       Clouds
# 3        5.68      SA  2023-02-19 21:37:05       Clouds
# 4       13.80      MR  2023-02-19 21:37:06       Clouds
# 5        2.86      CD  2023-02-19 21:37:06       Clouds
# 6       15.90      PF  2023-02-19 21:37:07       Clouds
# 7        4.00      US  2023-02-19 21:37:08         Rain
# 8       24.47      DK  2023-02-19 21:37:09       Clouds
# 9       14.97      MX  2023-02-19 21:34:37        Clear

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Date', 'City Weather'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ['City', 'Country', 'Lat', 'Lng', 
                    'Max Temp', 'Humidity', 'Cloudiness',
                    'Wind Speed', 'City Weather']

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]
# Display sample data

# %%
city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Kabalo      CD  -6.0500   26.9167     70.45        96         100
# 1         Kamenka      RU  51.3223   42.7678     28.18        96         100
# 2     Tuktoyaktuk      CA  69.4541 -133.0374    -25.60        68          75
# 3        Umm Lajj      SA  25.0213   37.2685     71.71        62          81
# 4      Nouadhibou      MR  20.9310  -17.0347     66.18        72          87
# ..            ...     ...      ...       ...       ...       ...         ...
# 687         Tabas      IR  33.5959   56.9244     46.62        42           0
# 688      Olafsvik      IS  64.8945  -23.7142     36.55        90         100
# 689  San Fernando      PH  15.0286  120.6898     78.53        88          96
# 690    Carutapera      BR  -1.1950  -46.0200     74.17        96         100
# 691        Garoua      CM   9.3000   13.4000     77.41        16           1
#
#      Wind Speed City Weather
# 0          4.14       Clouds
# 1          8.86       Clouds
# 2          5.75       Clouds
# 3          5.68       Clouds
# 4         13.80       Clouds
# ..          ...          ...
# 687        2.30        Clear
# 688       28.72       Clouds
# 689        0.34       Clouds
# 690        7.65       Clouds
# 691        4.34        Clear
#
# [692 rows x 9 columns]

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City             object
# Country          object
# Lat             float64
# Lng             float64
# Max Temp        float64
# Humidity          int64
# Cloudiness        int64
# Wind Speed      float64
# City Weather     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = r'C:\Users\ssala\Class\World_Weather_Analysis\Weather_Database/WeatherPy_Database.csv'

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="None")
